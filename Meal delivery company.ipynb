# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3C6A-BEA6
#
#  Directory of C:\Users\intel\python code\Api\AI & ML project\Meal delivery company
#
# 07/14/2020  07:49 PM    <DIR>          .
# 07/14/2020  07:49 PM    <DIR>          ..
# 07/10/2020  10:55 PM    <DIR>          .ipynb_checkpoints
# 07/10/2020  10:46 PM             1,661 fulfilment_center_info.csv
# 07/14/2020  07:49 PM            82,092 Meal delivery company.ipynb
# 07/10/2020  10:46 PM             1,096 meal_info.csv
# 07/11/2020  12:21 AM               510 one_to_ten_week_data.csv
# 07/10/2020  11:33 PM             8,858 one_to_ten_week_data.xlsx
# 07/10/2020  10:46 PM         1,239,576 test.csv
# 07/10/2020  10:46 PM        18,733,819 train.csv
#                7 File(s)     20,067,612 bytes
#                3 Dir(s)  76,067,708,928 bytes free

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as svm
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
sns.heatmap(df.corr(),annot = True)

# %%
x=df['week']
y=df['num_orders']

plt.plot(x, y, 'r')
plt.xlabel('Number of weeks')
plt.ylabel('Total number of orders')
plt.title('sales')
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.hist(y)
# Out:
# (array([4.54511e+05, 1.75500e+03, 2.08000e+02, 4.80000e+01, 1.80000e+01,
#         6.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([1.30000e+01, 2.44160e+03, 4.87020e+03, 7.29880e+03, 9.72740e+03,
#         1.21560e+04, 1.45846e+04, 1.70132e+04, 1.94418e+04, 2.18704e+04,
#         2.42990e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(y,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x83eeb59548>,
#   <matplotlib.lines.Line2D at 0x83eeb42888>],
#  'caps': [<matplotlib.lines.Line2D at 0x83eeb59f48>,
#   <matplotlib.lines.Line2D at 0x83eeb5de08>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x83eeb53f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x83eeb5df08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x83eeb62dc8>],
#  'means': []}

# %%
plt.boxplot(df['checkout_price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x83eebbbfc8>,
#   <matplotlib.lines.Line2D at 0x83eebbf988>],
#  'caps': [<matplotlib.lines.Line2D at 0x83eebbfa88>,
#   <matplotlib.lines.Line2D at 0x83eebc4908>],
#  'boxes': [<matplotlib.lines.Line2D at 0x83eebbb808>],
#  'medians': [<matplotlib.lines.Line2D at 0x83eebc4f88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x83eebc9888>],
#  'means': []}

# %%
plt.boxplot(df['base_price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x83eec23b88>,
#   <matplotlib.lines.Line2D at 0x83eec23c88>],
#  'caps': [<matplotlib.lines.Line2D at 0x83eec27b48>,
#   <matplotlib.lines.Line2D at 0x83eec27c48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x83eec23208>],
#  'medians': [<matplotlib.lines.Line2D at 0x83eec2bac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x83eec2bbc8>],
#  'means': []}

# %%
plt.step(x,y)

# %%
plt.bar(x,y)

# %%
# all_df=pd.read_csv('train.csv')

# %%
# all_df.info()

# %%
# all_x=all_df['week']
# all_y=all_df['num_orders']

# %%
# plt.bar(all_x,all_y)

# %%
# plt.scatter(all_x,all_y)

# %%
# plt.plot(all_x,all_y)

# %%
plt.fill_between(x,y)

# %%
df.describe()
# Out:
#                  id      week  center_id  meal_id  checkout_price  base_price  \
# count  1.000000e+01  10.00000       10.0     10.0       10.000000   10.000000
# mean   1.209504e+06   5.50000       11.0   1885.0      140.974000  141.074000
# std    1.287128e+05   3.02765        0.0      0.0        5.011933    4.972226
# min    1.007434e+06   1.00000       11.0   1885.0      133.860000  133.860000
# 25%    1.119658e+06   3.25000       11.0   1885.0      136.102500  136.102500
# 50%    1.195867e+06   5.50000       11.0   1885.0      143.560000  142.590000
# 75%    1.274214e+06   7.75000       11.0   1885.0      144.302500  145.302500
# max    1.425602e+06  10.00000       11.0   1885.0      146.530000  146.530000
#
#        emailer_for_promotion  homepage_featured   num_orders
# count                   10.0               10.0    10.000000
# mean                     0.0                0.0   999.300000
# std                      0.0                0.0    71.816201
# min                      0.0                0.0   891.000000
# 25%                      0.0                0.0   959.000000
# 50%                      0.0                0.0   993.000000
# 75%                      0.0                0.0  1046.750000
# max                      0.0                0.0  1107.000000

# %%
sns.pairplot(df)

# %%
sns.distplot(df['num_orders'])

# %%
sns.heatmap(df.corr(),annot = True)

# %%
df.columns
# Out:
# Index(['id', 'week', 'center_id', 'meal_id', 'checkout_price', 'base_price',
#        'emailer_for_promotion', 'homepage_featured', 'num_orders'],
#       dtype='object')

# %%
X = df[['center_id', 'meal_id', 'checkout_price', 'base_price',
       'emailer_for_promotion', 'homepage_featured',]]
y = df['num_orders']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state =101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)

# %%
predictions = lm.predict(X_test)
